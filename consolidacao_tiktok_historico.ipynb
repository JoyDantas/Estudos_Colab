# %% [markdown]
# <a href="https://colab.research.google.com/github/JoyDantas/Estudos_Colab/blob/main/consolidacao_tiktok_historico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
tiktok_itaucard = pd.read_csv('/content/drive/MyDrive/historico - tiktok/TiktokAds_Ad Performance_DPZT _ Itaucard_20210101-20220101.csv', sep=";")
tiktok_institucional = pd.read_csv('/content/drive/MyDrive/historico - tiktok/TiktokAds_Ad Performance_DPZT _ Itaú Institucional_20210101-20220101.csv', sep=';')
tiktok_mc = pd.read_csv("/content/drive/MyDrive/historico - tiktok/TiktokAds_Ad Performance_DPZT _ McDonald's_20210101-20220101.csv", sep=";")
tiktok_natura = pd.read_csv('/content/drive/MyDrive/historico - tiktok/TiktokAds_Ad Performance_DPZT _ Natura_20210101-20220101.csv', sep=";")

# %%
concat_frames = [tiktok_itaucard, tiktok_institucional, tiktok_mc, tiktok_natura]

# %%
consolidado_tiktok = pd.concat(concat_frames)

# %%
## conferindo formatos
consolidado_tiktok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45841 entries, 0 to 685
# Data columns (total 40 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               45841 non-null  object
#  1   Ad ID                              45841 non-null  object
#  2   Cliente                            45841 non-null  object
#  3   Ad Name                            45841 non-null  object
#  4   Ads Format                         45841 non-null  object
#  5   Text                               45841 non-null  object
#  6   Ad Group ID                        44208 non-null  object
#  7   Ad Group Name                      44208 non-null  object
#  8   Campaign ID                        44208 non-null  object
#  9   Campaign Name                      44208 non-null  object
#  10  Placements Types                   44208 non-null  object
# ...

# %%
## contando valores null
print(consolidado_tiktok[consolidado_tiktok['Cost'].isnull()])
# Out:
#              Date        Ad ID  ... Anchor Clicks Rate Clicks on Music Disc
# 21     22/01/2021  1,68961E+15  ...                NaN                  NaN
# 27     23/01/2021  1,68961E+15  ...                NaN                  NaN
# 47     24/01/2021  1,68961E+15  ...                NaN                  NaN
# 61     25/01/2021  1,68961E+15  ...                NaN                  NaN
# 86     26/01/2021  1,68961E+15  ...                NaN                  NaN
# ...           ...          ...  ...                ...                  ...
# 31643  12/09/2021  1,69369E+15  ...                NaN                  NaN
# 31702  13/09/2021  1,69369E+15  ...                NaN                  NaN
# 32106  15/09/2021  1,69369E+15  ...                NaN                  NaN
# 40913  23/11/2021  1,69134E+15  ...                NaN                  NaN
# 43066  20/12/2021  1,69134E+15  ...                NaN                  NaN
#
# [1633 rows x 40 columns]

# %%
consolidado_tiktok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45841 entries, 0 to 685
# Data columns (total 40 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Date                               45841 non-null  object
#  1   Ad ID                              45841 non-null  object
#  2   Cliente                            45841 non-null  object
#  3   Ad Name                            45841 non-null  object
#  4   Ads Format                         45841 non-null  object
#  5   Text                               45841 non-null  object
#  6   Ad Group ID                        44208 non-null  object
#  7   Ad Group Name                      44208 non-null  object
#  8   Campaign ID                        44208 non-null  object
#  9   Campaign Name                      44208 non-null  object
#  10  Placements Types                   44208 non-null  object
# ...

# %%
consolidado_tiktok.head()
# Out:
#          Date        Ad ID  ... Anchor Clicks Rate Clicks on Music Disc
# 0  22/06/2021  1,70327E+15  ...                0.0                  NaN
# 1  22/06/2021  1,70327E+15  ...                0.0                  NaN
# 2  23/06/2021  1,70327E+15  ...                0.0                  NaN
# 3  23/06/2021  1,70327E+15  ...                0.0                  NaN
# 4  24/06/2021  1,70327E+15  ...                0.0                  NaN
#
# [5 rows x 40 columns]

# %%
#consolidado_tiktok.to_csv('consolidado_tiktok.csv',sep='\t', encoding="utf-8")
#pd.set_option('float_format', '{:.2f}'.format)

# %%
consolidado_tiktok.to_csv('consolidado_tiktok.csv',float_format='%.f', index=False, header=True)
#df.to_csv('test.out', float_format = '%.2f', index = False, header = False)
